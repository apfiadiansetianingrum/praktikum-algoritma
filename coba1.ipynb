# %% [markdown]
# <a href="https://colab.research.google.com/github/apfiadiansetianingrum/praktikum-algoritma/blob/master/coba1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Barang:
  def __init__(self,kode,nama,harga,stok):
    self.kode=kode
    self.nama=nama
    self.harga=harga
    self.stok=stok


  def update_stok(self, jumlah):
    self.stok += jumlah

  def info_barang(self):
    return f"Kode\t: {self.kode}\nNama\t: {self.nama}\nHarga\t: {self.harga}\nStok\t: {self.stok}"



pensil=Barang('AAO','Pensil',1000,100)
print(pensil.info_barang())
pensil.update_stok(-20)
print("Stok pensil saat ini : ", pensil.stok)
# Out:
# Kode	: AAO
# Nama	: Pensil
# Harga	: 1000
# Stok	: 100
# Stok pensil saat ini :  80

# %%
class barang:
  def __init__(self,kode,nama,harga,stok):
    self.kode=kode
    self.nama=nama
    self.harga=harga
    self.stok=stok


  def update_stok(self, jumlah):
     if self.stok + jumlah<0:
      raise ValueError("Stok tidak negatif")
     self.stok += jumlah

  def info_barang(self):
    return f"Kode\t: {self.kode}\nNama\t: {self.nama}\nHarga\t: {self.harga}\nStok\t: {self.stok}"

daftarbarang=[]
daftarbarangdict={}

def tambah_barang():
  daftarbarang.append(barang)
  daftarbarangdict[barang.kode_barang]=barang

def tampilkaninventaris():
  for barang in daftarbarang:
    print(barang.info_barang())

def caribarang(kode):
  if kode in daftarbarangdict:
    print(daftarbarangdict[kode].info_barang())
  else:
    print("Barang tidak ditemukan")

def main():
  while True:
    print("\nMenu:")
    print("1. Tambah Barang")
    print("2. Tampilkan Inventaris")
    print("3. Cari Barang")
    print("4. update stok")
    print("5. Keluar")

    pilihan = input("Pilih menu (1/2/3/4/5): ")

    if pilihan == "1":
      kode = input("Masukkan Kode Barang: ")
      Nama=input("Masukkan Nama Barang: ")
      Harga=float(input("Masukkan Harga Barang: "))
      Stok=int(input("Masukkan Stok Barang: "))
      barang= barang(kode,Nama,Harga,Stok)
      tambah_barang(barang)
      print("Barang berhasil ditambahkan!")

    elif pilihan == "2":
      tampilkaninventaris()

    elif pilihan == "3":
      kode = input("Masukkan Kode Barang yang ingin dicari: ")
      caribarang(kode)

    elif pilihan == "4":
      kode = input("Masukkan Kode Barang yang ingin diupdate stoknya: ")
      jumlah = int(input("Masukkan Jumlah yang ingin ditambah/dikurangi: "))
      try:
        jumlah= int(jumlah)
        if kode in daftarbarangdict:
            daftarbarangdict[kode].update_stok(jumlah)
            print("Stok berhasil diupdate!")
        else:
            print("Barang tidak ditemukan")
      except ValueError:
          print("jumlah stok harus berupa angka.")

    elif pilihan == "5":
      print("Terima kasih! Program selesai.")
      break

    else:
      print("Pilihan tidak valid. Silakan coba lagi.")

if __name__ == "__main__":
  main()
# Out:
# Menu:
# 1. Tambah Barang
# 2. Tampilkan Inventaris
# 3. Cari Barang
# 4. update stok
# 5. Keluar
# Pilih menu (1/2/3/4/5): 1
# Masukkan Kode Barang: AA0
# Masukkan Nama Barang: Pensil
# Masukkan Harga Barang: 15000
# Masukkan Stok Barang: 80
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-2-3bb80e27d355> in <cell line: 82>()
#      81
#      82 if __name__ == "__main__":
# ---> 83   main()
#
# <ipython-input-2-3bb80e27d355> in main()
#      49       Harga=float(input("Masukkan Harga Barang: "))
#      50       Stok=int(input("Masukkan Stok Barang: "))
# ---> 51       barang= barang(kode,Nama,Harga,Stok)
#      52       tambah_barang(barang)
#      53       print("Barang berhasil ditambahkan!")
#
# UnboundLocalError: local variable 'barang' referenced before assignment

# %%
class Barang:
    def __init__(self, kode, nama, harga, stok):
        self.kode = kode
        self.nama = nama
        self.harga = harga
        self.stok = stok

    def update_stok(self, jumlah):
        if self.stok + jumlah < 0:
            raise ValueError("Stok tidak negatif")
        self.stok += jumlah

    def info_barang(self):
        return f"Kode\t: {self.kode}\nNama\t: {self.nama}\nHarga\t: {self.harga}\nStok\t: {self.stok}"

daftarbarang = []
daftarbarangdict = {}

def tambah_barang(brg):
    daftarbarang.append(brg)
    daftarbarangdict[brg.kode] = brg


def tampilkaninventaris():
    for barang in daftarbarang:
        print(barang.info_barang())

def caribarang(kode):
    if kode in daftarbarangdict:
        print(daftarbarangdict[kode].info_barang())
    else:
        print("Barang tidak ditemukan")

def main():
    while True:
        print("\nMenu:")
        print("1. Tambah Barang")
        print("2. Tampilkan Inventaris")
        print("3. Cari Barang")
        print("4. update stok")
        print("5. Keluar")

        pilihan = input("Pilih menu (1/2/3/4/5): ")

        if pilihan == "1":
            kode = input("Masukkan Kode Barang: ")
            Nama = input("Masukkan Nama Barang: ")
            Harga = float(input("Masukkan Harga Barang: "))
            Stok = int(input("Masukkan Stok Barang: "))
            brg = Barang(kode, Nama, Harga, Stok)
            tambah_barang(brg)
            print("Barang berhasil ditambahkan!")

        elif pilihan == "2":
            tampilkaninventaris()

        elif pilihan == "3":
            kode = input("Masukkan Kode Barang yang ingin dicari: ")
            caribarang(kode)

        elif pilihan == "4":
            kode = input("Masukkan Kode Barang yang ingin diupdate stoknya: ")
            jumlah = int(input("Masukkan Jumlah yang ingin ditambah/dikurangi: "))
            try:
                jumlah = int(jumlah)
                if kode in daftarbarangdict:
                    daftarbarangdict[kode].update_stok(jumlah)
                    print("Stok berhasil diupdate!")
                else:
                    print("Barang tidak ditemukan")
            except ValueError:
                print("jumlah stok harus berupa angka.")

        elif pilihan == "5":
            print("Terima kasih! Program selesai.")
            break

        else:
            print("Pilihan tidak valid. Silakan coba lagi.")

if __name__ == "__main__":
    main()
# Out:
# Menu:
# 1. Tambah Barang
# 2. Tampilkan Inventaris
# 3. Cari Barang
# 4. update stok
# 5. Keluar
# Pilih menu (1/2/3/4/5): 1
# Masukkan Kode Barang: AA0
# Masukkan Nama Barang: Gas
# Masukkan Harga Barang: 22000
# Masukkan Stok Barang: 100
# Barang berhasil ditambahkan!
#
# Menu:
# 1. Tambah Barang
# 2. Tampilkan Inventaris
# 3. Cari Barang
# 4. update stok
# 5. Keluar
# Pilih menu (1/2/3/4/5): 2
# Kode	: AA0
# Nama	: Gas
# Harga	: 22000.0
# Stok	: 100
#
# Menu:
# 1. Tambah Barang
# 2. Tampilkan Inventaris
# 3. Cari Barang
# 4. update stok
# 5. Keluar
# Pilih menu (1/2/3/4/5): 2
# Kode	: AA0
# Nama	: Gas
# Harga	: 22000.0
# Stok	: 100
#
# Menu:
# 1. Tambah Barang
# 2. Tampilkan Inventaris
# 3. Cari Barang
# 4. update stok
# 5. Keluar
# Pilih menu (1/2/3/4/5): 3
# Masukkan Kode Barang yang ingin dicari: AA0
# Kode	: AA0
# Nama	: Gas
# Harga	: 22000.0
# Stok	: 100
#
# Menu:
# 1. Tambah Barang
# 2. Tampilkan Inventaris
# 3. Cari Barang
# 4. update stok
# 5. Keluar
# ...
